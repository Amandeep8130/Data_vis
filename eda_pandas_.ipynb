# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'/content/sample_eda_dataset.csv')

# %%
df.shape
# Out:
# (100, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           100 non-null    int64
#  1   Age                  100 non-null    int64
#  2   Gender               100 non-null    object
#  3   Annual_Income        100 non-null    int64
#  4   Spending_Score       100 non-null    int64
#  5   City                 100 non-null    object
#  6   Purchased            100 non-null    object
#  7   Tenure_Years         100 non-null    int64
#  8   Satisfaction_Rating  100 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 7.2+ KB

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Annual_Income', 'Spending_Score',
#        'City', 'Purchased', 'Tenure_Years', 'Satisfaction_Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CustomerID        Age  Annual_Income  Spending_Score  Tenure_Years  \
# count  100.000000  100.00000      100.00000      100.000000    100.000000
# mean    50.500000   40.88000    72967.25000       49.160000      6.890000
# std     29.011492   13.99082    29960.97386       29.216614      4.220908
# min      1.000000   18.00000    20854.00000        1.000000      0.000000
# 25%     25.750000   30.50000    46067.25000       24.750000      3.000000
# 50%     50.500000   41.00000    73558.50000       47.000000      7.000000
# 75%     75.250000   53.25000   103349.00000       69.750000     11.000000
# max    100.000000   64.00000   118506.00000       99.000000     14.000000
#
#        Satisfaction_Rating
# count           100.000000
# mean              3.180000
# std               1.479694
# min               1.000000
# 25%               2.000000
# 50%               3.000000
# 75%               4.250000
# max               5.000000

# %%
df.head(5)
# Out:
#    CustomerID  Age  Gender  Annual_Income  Spending_Score       City  \
# 0           1   56  Female          41976              60      Delhi
# 1           2   46  Female          64262               2     Mumbai
# 2           3   32    Male          43776               1     Mumbai
# 3           4   60    Male          50080              48  Bangalore
# 4           5   25    Male          86842              12     Mumbai
#
#   Purchased  Tenure_Years  Satisfaction_Rating
# 0       Yes             3                    1
# 1        No             1                    5
# 2       Yes             0                    4
# 3        No             6                    4
# 4        No             7                    4

# %%
df.sample(8)
# Out:
#     CustomerID  Age  Gender  Annual_Income  Spending_Score       City  \
# 81          82   33  Female          28680              46    Kolkata
# 33          34   32    Male         109474              35  Bangalore
# 34          35   64    Male          43664              80      Delhi
# 9           10   28    Male          29474              99     Mumbai
# 92          93   62  Female          67254              97    Kolkata
# 11          12   41    Male          41959              48      Delhi
# 25          26   29    Male          74384              89    Kolkata
# 31          32   45  Female          72733              66     Mumbai
#
#    Purchased  Tenure_Years  Satisfaction_Rating
# 81        No            12                    5
# 33        No             8                    4
# 34       Yes             6                    5
# 9         No             0                    2
# 92        No             5                    5
# ...

# %%
df.tail(8)
# Out:
#     CustomerID  Age  Gender  Annual_Income  Spending_Score     City Purchased  \
# 92          93   62  Female          67254              97  Kolkata        No
# 93          94   18  Female          41918              63    Delhi       Yes
# 94          95   42  Female         105981              85  Chennai       Yes
# 95          96   24    Male          80713              32  Kolkata        No
# 96          97   26  Female          50306              87  Chennai        No
# 97          98   41  Female          36646              33   Mumbai       Yes
# 98          99   18    Male          66843              67   Mumbai       Yes
# 99         100   61  Female         116601              18  Kolkata       Yes
#
#     Tenure_Years  Satisfaction_Rating
# 92             5                    5
# 93             2                    5
# 94             7                    1
# 95            12                    1
# 96             0                    2
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID             0
# Age                    0
# Gender                 0
# Annual_Income          0
# Spending_Score         0
# City                   0
# Purchased              0
# Tenure_Years           0
# Satisfaction_Rating    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head(8)
# Out:
#    CustomerID  Age  Gender  Annual_Income  Spending_Score       City  \
# 0           1   56  Female          41976              60      Delhi
# 1           2   46  Female          64262               2     Mumbai
# 2           3   32    Male          43776               1     Mumbai
# 3           4   60    Male          50080              48  Bangalore
# 4           5   25    Male          86842              12     Mumbai
# 5           6   38    Male          81373              69     Mumbai
# 6           7   56  Female          26776              37  Bangalore
# 7           8   36    Male         112787              32     Mumbai
#
#   Purchased  Tenure_Years  Satisfaction_Rating
# 0       Yes             3                    1
# 1        No             1                    5
# 2       Yes             0                    4
# 3        No             6                    4
# 4        No             7                    4
# 5       Yes             6                    3
# ...

# %%
df.set_index('CustomerID', inplace = True)

# %%
df.head(3)
# Out:
#             Age  Gender  Annual_Income  Spending_Score    City Purchased  \
# CustomerID
# 1            56  Female          41976              60   Delhi       Yes
# 2            46  Female          64262               2  Mumbai        No
# 3            32    Male          43776               1  Mumbai       Yes
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# 2                      1                    5
# 3                      0                    4

# %%
#rename
df.rename(columns = {'Annual_Income':'Income'}, inplace = True)

# %%
df.head(5)
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 3            32    Male   43776               1     Mumbai       Yes
# 4            60    Male   50080              48  Bangalore        No
# 5            25    Male   86842              12     Mumbai        No
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# 2                      1                    5
# 3                      0                    4
# 4                      6                    4
# 5                      7                    4

# %%
df['Age']:6

# %%
df
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 3            32    Male   43776               1     Mumbai       Yes
# 4            60    Male   50080              48  Bangalore        No
# 5            25    Male   86842              12     Mumbai        No
# ...         ...     ...     ...             ...        ...       ...
# 96           24    Male   80713              32    Kolkata        No
# 97           26  Female   50306              87    Chennai        No
# 98           41  Female   36646              33     Mumbai       Yes
# 99           18    Male   66843              67     Mumbai       Yes
# 100          61  Female  116601              18    Kolkata       Yes
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# ...

# %%
df[df['Age']>20]
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 3            32    Male   43776               1     Mumbai       Yes
# 4            60    Male   50080              48  Bangalore        No
# 5            25    Male   86842              12     Mumbai        No
# ...         ...     ...     ...             ...        ...       ...
# 95           42  Female  105981              85    Chennai       Yes
# 96           24    Male   80713              32    Kolkata        No
# 97           26  Female   50306              87    Chennai        No
# 98           41  Female   36646              33     Mumbai       Yes
# 100          61  Female  116601              18    Kolkata       Yes
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# ...

# %%
df['City']
# Out:
# CustomerID
# 1          Delhi
# 2         Mumbai
# 3         Mumbai
# 4      Bangalore
# 5         Mumbai
#          ...
# 96       Kolkata
# 97       Chennai
# 98        Mumbai
# 99        Mumbai
# 100      Kolkata
# Name: City, Length: 100, dtype: object

# %%
type(df['City'])
# Out:
# pandas.core.series.Series

# %%
df[['Age','City']]
# Out:
#             Age       City
# CustomerID
# 1            56      Delhi
# 2            46     Mumbai
# 3            32     Mumbai
# 4            60  Bangalore
# 5            25     Mumbai
# ...         ...        ...
# 96           24    Kolkata
# 97           26    Chennai
# 98           41     Mumbai
# 99           18     Mumbai
# 100          61    Kolkata
#
# [100 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Age                        56
# Gender                 Female
# Income                  41976
# Spending_Score             60
# City                    Delhi
# Purchased                 Yes
# Tenure_Years                3
# Satisfaction_Rating         1
# Name: 1, dtype: object

# %%
df.iloc[:5]
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 3            32    Male   43776               1     Mumbai       Yes
# 4            60    Male   50080              48  Bangalore        No
# 5            25    Male   86842              12     Mumbai        No
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# 2                      1                    5
# 3                      0                    4
# 4                      6                    4
# 5                      7                    4

# %%
df.iloc[:20:3]
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 4            60    Male   50080              48  Bangalore        No
# 7            56  Female   26776              37  Bangalore       Yes
# 10           28    Male   29474              99     Mumbai        No
# 13           53  Female   25530              80      Delhi        No
# 16           20    Male  117504              24     Mumbai        No
# 19           41    Male   86199              24     Mumbai        No
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# 4                      6                    4
# 7                     13                    5
# 10                     0                    2
# 13                     6                    3
# 16                     8                    2
# 19                     0                    4

# %%
df[df['Gender']== 'Female']
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 7            56  Female   26776              37  Bangalore       Yes
# 13           53  Female   25530              80      Delhi        No
# 15           41  Female   23748              20    Kolkata       Yes
# 17           39  Female  118098              54     Mumbai        No
# 20           61  Female   54766              75      Delhi        No
# 21           47  Female   93530              72    Kolkata       Yes
# 22           55  Female  113557              36    Chennai        No
# 24           38  Female  115839              84      Delhi       Yes
# 27           39  Female   71005              99    Chennai        No
# 28           61  Female   66576              25      Delhi        No
# ...

# %%
df[df['Gender']== 'Female']
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 7            56  Female   26776              37  Bangalore       Yes
# 13           53  Female   25530              80      Delhi        No
# 15           41  Female   23748              20    Kolkata       Yes
# 17           39  Female  118098              54     Mumbai        No
# 20           61  Female   54766              75      Delhi        No
# 21           47  Female   93530              72    Kolkata       Yes
# 22           55  Female  113557              36    Chennai        No
# 24           38  Female  115839              84      Delhi       Yes
# 27           39  Female   71005              99    Chennai        No
# 28           61  Female   66576              25      Delhi        No
# ...

# %%
df[df['Gender']== "Male"]
# Out:
#             Age Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 3            32   Male   43776               1     Mumbai       Yes
# 4            60   Male   50080              48  Bangalore        No
# 5            25   Male   86842              12     Mumbai        No
# 6            38   Male   81373              69     Mumbai       Yes
# 8            36   Male  112787              32     Mumbai        No
# 9            40   Male   75016               9     Mumbai        No
# 10           28   Male   29474              99     Mumbai        No
# 11           28   Male   78053              19      Delhi       Yes
# 12           41   Male   41959              48      Delhi        No
# 14           57   Male  114856               3  Bangalore        No
# 16           20   Male  117504              24     Mumbai        No
# 18           19   Male   33545              33  Bangalore       Yes
# 19           41   Male   86199              24     Mumbai        No
# ...

# %%
k_c =df[df['City']== 'Kolkata']

# %%
k_c
# Out:
#             Age  Gender  Income  Spending_Score     City Purchased  \
# CustomerID
# 15           41  Female   23748              20  Kolkata       Yes
# 21           47  Female   93530              72  Kolkata       Yes
# 26           29    Male   74384              89  Kolkata        No
# 37           20    Male  105616              41  Kolkata        No
# 45           42    Male   75680               8  Kolkata       Yes
# 47           26  Female  107092              67  Kolkata       Yes
# 51           45    Male   83734              76  Kolkata       Yes
# 53           24  Female   72662              86  Kolkata        No
# 57           52    Male   57157              51  Kolkata       Yes
# 67           46    Male   62107              64  Kolkata       Yes
# 69           43    Male   71663              69  Kolkata        No
# 72           27    Male   69811              19  Kolkata        No
# 79           40    Male   22911              92  Kolkata        No
# ...

# %%
print(len(k_c))
# Out:
# 22

# %%
print(k_c['Income'].max())
# Out:
# 116601

# %%
print(k_c['Income'].min())
# Out:
# 21802

# %%
print(k_c['Income'].mean())
# Out:
# 73856.63636363637

# %%
df.head(4)
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 3            32    Male   43776               1     Mumbai       Yes
# 4            60    Male   50080              48  Bangalore        No
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# 2                      1                    5
# 3                      0                    4
# 4                      6                    4

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      56
# Female    44
# Name: count, dtype: int64

# %%
df['City'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['City'].value_counts()
# Out:
# City
# Mumbai       28
# Kolkata      22
# Chennai      20
# Delhi        18
# Bangalore    12
# Name: count, dtype: int64

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# No     51
# Yes    49
# Name: count, dtype: int64

# %%
df['Purchased'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Purchased'>

# %%
df['Purchased'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['City'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='City'>

# %%
df['Gender'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df['Gender'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['City'].value_counts().sort_values()
# Out:
# City
# Bangalore    12
# Delhi        18
# Chennai      20
# Kolkata      22
# Mumbai       28
# Name: count, dtype: int64

# %%
df.drop(['Gender', 'City', 'Purchased'], axis=1).corr()
# Out:
#                           Age    Income  Spending_Score  Tenure_Years  \
# Age                  1.000000  0.049819        0.072673      0.045102
# Income               0.049819  1.000000       -0.115227      0.201849
# Spending_Score       0.072673 -0.115227        1.000000      0.028566
# Tenure_Years         0.045102  0.201849        0.028566      1.000000
# Satisfaction_Rating  0.084488 -0.030114       -0.045066     -0.003267
#
#                      Satisfaction_Rating
# Age                             0.084488
# Income                         -0.030114
# Spending_Score                 -0.045066
# Tenure_Years                   -0.003267
# Satisfaction_Rating             1.000000

# %%
df
# Out:
#             Age  Gender  Income  Spending_Score       City Purchased  \
# CustomerID
# 1            56  Female   41976              60      Delhi       Yes
# 2            46  Female   64262               2     Mumbai        No
# 3            32    Male   43776               1     Mumbai       Yes
# 4            60    Male   50080              48  Bangalore        No
# 5            25    Male   86842              12     Mumbai        No
# ...         ...     ...     ...             ...        ...       ...
# 96           24    Male   80713              32    Kolkata        No
# 97           26  Female   50306              87    Chennai        No
# 98           41  Female   36646              33     Mumbai       Yes
# 99           18    Male   66843              67     Mumbai       Yes
# 100          61  Female  116601              18    Kolkata       Yes
#
#             Tenure_Years  Satisfaction_Rating
# CustomerID
# 1                      3                    1
# ...

# %%
df_n = df.select_dtypes(include = [np.number])
df_c = df.select_dtypes(include = 'object')

# %%
df_n
# Out:
#             Age  Income  Spending_Score  Tenure_Years  Satisfaction_Rating
# CustomerID
# 1            56   41976              60             3                    1
# 2            46   64262               2             1                    5
# 3            32   43776               1             0                    4
# 4            60   50080              48             6                    4
# 5            25   86842              12             7                    4
# ...         ...     ...             ...           ...                  ...
# 96           24   80713              32            12                    1
# 97           26   50306              87             0                    2
# 98           41   36646              33             5                    1
# 99           18   66843              67             3                    3
# 100          61  116601              18             0                    5
#
# [100 rows x 5 columns]

# %%
df_c
# Out:
#             Gender       City Purchased
# CustomerID
# 1           Female      Delhi       Yes
# 2           Female     Mumbai        No
# 3             Male     Mumbai       Yes
# 4             Male  Bangalore        No
# 5             Male     Mumbai        No
# ...            ...        ...       ...
# 96            Male    Kolkata        No
# 97          Female    Chennai        No
# 98          Female     Mumbai       Yes
# 99            Male     Mumbai       Yes
# 100         Female    Kolkata       Yes
#
# [100 rows x 3 columns]

# %%
sns.heatmap(df_n.corr())
# Out:
# <Axes: >

# %%
sns.scatterplot(x = 'Age', y = 'Income', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.pairplot(df_n)
plt.show()

# %%
#strong columns
sns.scatterplot(x = 'Age', y = 'Income', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.scatterplot(x ='Spending_Score', y = 'Income', data = df )
# Out:
# <Axes: xlabel='Spending_Score', ylabel='Income'>

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
df.hist(bins=30, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Income'}>],
#        [<Axes: title={'center': 'Spending_Score'}>,
#         <Axes: title={'center': 'Tenure_Years'}>],
#        [<Axes: title={'center': 'Satisfaction_Rating'}>, <Axes: >]],
#       dtype=object)
